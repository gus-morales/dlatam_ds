# %% [markdown]
# # Desafío Miércoles Semana 3 - Estimando curvas normales

# %% [markdown]
# #### Gustavo Morales, G10 - 11.Sep.2019

# %% [markdown]
# ### Ejercicio 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
fname = "subsample_gmc_demo.csv"
df = pd.read_csv(fname)
df = df.drop(columns='Unnamed: 0')

# %%
df
# Out:
#     undp_hdi ccodealp  ht_region     gle_cgdpc     imf_pop  ffp_hf   wef_qes  \
# 0      0.823      HRV          1   18020.41000    4.238000     4.5  3.225567
# 1      0.706      BLZ         10    6649.14010    0.350000     6.5  2.651881
# 2      0.923      DNK          5   37406.76200    5.627000     1.9  4.812749
# 3      0.438      MLI          4    1063.26000   14.854000     8.4  3.003276
# 4      0.775      SRB          1   11343.92000    7.167000     5.3  3.058159
# 5      0.937      AUS          5   38611.94900   23.621000     1.0  4.798969
# 6      0.798      ROU          1   14563.14000   19.952999     4.5  3.833498
# 7      0.846      LTU          1   17559.75000    2.932000     4.2  3.930861
# 8      0.764      LKA          8    5466.87010   20.541000     7.8  4.644127
# 9      0.913      NZL          5   26481.36900    4.555000     2.1  5.318371
# 10     0.888      SVN          1   24456.56100    2.061000     2.8  4.073011
# ...

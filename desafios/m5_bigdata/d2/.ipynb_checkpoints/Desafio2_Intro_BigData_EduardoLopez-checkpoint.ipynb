# %% [markdown]
# ![alttext](logo.png)

# %% [markdown]
# ### Nombre Alumno: Eduardo López
# ### Generación :  G10
# ### Profesores :  Robert Escalante - Gianina Salomó
# ### Fecha : Lunes 20 de abril de 2020

# %% [markdown]
# # Ejercicio 1: Ingesta de datos semiestructurados
# * Utilizando las librerías requests y json, realize una consulta a la API BallDontLie https://www.balldontlie.io/.
# * Mediante esta API, genere una consulta de 100 juegos (busquen el endpoint Get All Games en la página, dentro de Games). Puede usar la opción ?per_page=100 en la dirección de la API para lograr esto.
# * Guarde la consulta en una variable, y asegúrese que ésta sea semiestructurada. Consulte los datos y metadatos asociados.
# * Dentro de la lista de datos, comente cuáles son las llaves de cada registro.

# %%
import requests

# %%
response = requests.get('https://www.balldontlie.io/api/v1/games/?per_page=100')

# %%
response
# Out:
# <Response [200]>

# %%
to_df = response.json()

# %%
print("Dimensiones del json: ", len(to_df))
# Out:
# Dimensiones del json:  2

# %%
print("Tipo de objeto en la segunda dimensión: ", type(to_df['data']))
print("Largo de la segunda dimension: ", len(to_df["data"]))
# Out:
# Tipo de objeto en la segunda dimensión:  <class 'list'>
# Largo de la segunda dimension:  100

# %% [markdown]
# Llaves de cada registro

# %%
to_df["data"][0]
# Out:
# {'id': 47179,
#  'date': '2019-01-30T00:00:00.000Z',
#  'home_team': {'id': 2,
#   'abbreviation': 'BOS',
#   'city': 'Boston',
#   'conference': 'East',
#   'division': 'Atlantic',
#   'full_name': 'Boston Celtics',
#   'name': 'Celtics'},
#  'home_team_score': 126,
#  'period': 4,
#  'postseason': False,
#  'season': 2018,
#  'status': 'Final',
#  'time': ' ',
#  'visitor_team': {'id': 4,
#   'abbreviation': 'CHA',
#   'city': 'Charlotte',
#   'conference': 'East',
#   'division': 'Southeast',
#   'full_name': 'Charlotte Hornets',
#   'name': 'Hornets'},
#  'visitor_team_score': 94}

# %% [markdown]
# # Ejercicio 2: Organización de los datos
# * En base a los datos consultados en la API, genere un objeto pd.DataFrame con la siguiente estructura:

# %%
def json_to_row(json_entry):
    season = json_entry['season']
    period = json_entry['period']
    home = json_entry['home_team']["full_name"]
    home_conference = json_entry['home_team']["conference"]
    home_division = json_entry['home_team']["division"]
    visitor = json_entry['visitor_team']['full_name']
    visitor_conference = json_entry['visitor_team']['conference']
    visitor_division = json_entry["visitor_team"]["division"]
    home_score = json_entry["home_team_score"]
    visitor_score = json_entry["visitor_team_score"]
    home_differential = json_entry["home_team_score"] - json_entry["visitor_team_score"]
    visitor_differential = json_entry["visitor_team_score"] - json_entry["home_team_score"]
    # Aqui creo que faltan unas 3 tablas
    
    return [season,period,home,home_conference,home_division,visitor,visitor_conference,
            visitor_division,home_score,visitor_score,home_differential,visitor_differential]

# %%
import pandas as pd 
df = pd.DataFrame(list(map(json_to_row, to_df["data"])))

# %%
df
# Out:
#        0  1                    2     3          4                       5  \
# 0   2018  4       Boston Celtics  East   Atlantic       Charlotte Hornets
# 1   2018  4       Boston Celtics  East   Atlantic             LA Clippers
# 2   2018  4   Philadelphia 76ers  East   Atlantic          Denver Nuggets
# 3   2018  4   Washington Wizards  East  Southeast     Cleveland Cavaliers
# 4   2018  4     Sacramento Kings  West    Pacific              Miami Heat
# ..   ... ..                  ...   ...        ...                     ...
# 95  2018  4   Washington Wizards  East  Southeast          Indiana Pacers
# 96  2018  4        Brooklyn Nets  East   Atlantic  Portland Trail Blazers
# 97  2018  4  Cleveland Cavaliers  East    Central            Phoenix Suns
# 98  2018  4        Brooklyn Nets  East   Atlantic      Washington Wizards
# 99  2018  4       Indiana Pacers  East    Central    New Orleans Pelicans
#
#        6          7    8    9  10  11
# 0   East  Southeast  126   94  32 -32
# 1   West    Pacific  112  123 -11  11
# 2   West  Northwest  117  110   7  -7
# 3   East    Central  119  106  13 -13
# 4   East  Southeast  102   96   6  -6
# ..   ...        ...  ...  ...  ..  ..
# 95  East    Central  112  119  -7   7
# 96  West  Northwest   99  113 -14  14
# 97  West    Pacific  111   98  13 -13
# 98  East  Southeast  116  125  -9   9
# 99  West  Southwest  126  111  15 -15
#
# [100 rows x 12 columns]

# %%
df.rename(columns={0:'season',
                   1:'period',
                   2:'home',
                   3:'home_conference',
                   4:'home_division',
                   5:'visitor',
                   6:'visitor_conference',
                   7:'visitor_division',
                   8:'home_score',
                   9:'visitor_score',
                   10:'home_differential',
                   11:'visitor_differential'},
               inplace = True)

# %%
df
# Out:
#     season  period                 home home_conference home_division  \
# 0     2018       4       Boston Celtics            East      Atlantic
# 1     2018       4       Boston Celtics            East      Atlantic
# 2     2018       4   Philadelphia 76ers            East      Atlantic
# 3     2018       4   Washington Wizards            East     Southeast
# 4     2018       4     Sacramento Kings            West       Pacific
# ..     ...     ...                  ...             ...           ...
# 95    2018       4   Washington Wizards            East     Southeast
# 96    2018       4        Brooklyn Nets            East      Atlantic
# 97    2018       4  Cleveland Cavaliers            East       Central
# 98    2018       4        Brooklyn Nets            East      Atlantic
# 99    2018       4       Indiana Pacers            East       Central
#
#                    visitor visitor_conference visitor_division  home_score  \
# 0        Charlotte Hornets               East        Southeast         126
# 1              LA Clippers               West          Pacific         112
# 2           Denver Nuggets               West        Northwest         117
# 3      Cleveland Cavaliers               East          Central         119
# 4               Miami Heat               East        Southeast         102
# ..                     ...                ...              ...         ...
# 95          Indiana Pacers               East          Central         112
# 96  Portland Trail Blazers               West        Northwest          99
# 97            Phoenix Suns               West          Pacific         111
# 98      Washington Wizards               East        Southeast         116
# 99    New Orleans Pelicans               West        Southwest         126
#
#     visitor_score  home_differential  visitor_differential
# 0              94                 32                   -32
# 1             123                -11                    11
# 2             110                  7                    -7
# 3             106                 13                   -13
# 4              96                  6                    -6
# ..            ...                ...                   ...
# 95            119                 -7                     7
# 96            113                -14                    14
# 97             98                 13                   -13
# 98            125                 -9                     9
# 99            111                 15                   -15
#
# [100 rows x 12 columns]
